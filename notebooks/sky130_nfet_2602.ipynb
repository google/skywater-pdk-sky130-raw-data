# %%
from utils.read_data import read_iv
from utils.plot_iv import plot_idvg, plot_idvd
from matplotlib import pyplot as plt

# %%
data = read_iv('5290', 10, meas_mode='idvg')
ax = plt.gca()
axt = ax.twinx()


for dut_info, df in data:
    print(dut_info)
    plot_idvg(df, (ax, axt))
# Out:
# DUTinfo(die=1, mod='5290', idx=10, flavor='nshort', W=9.400000000000001e-07, L=1.5000000000000002e-07, meas_mode='idvg', VG=None, VD=0.05, VB=0.0, T=300.0)
# DUTinfo(die=1, mod='5290', idx=10, flavor='nshort', W=9.400000000000001e-07, L=1.5000000000000002e-07, meas_mode='idvg', VG=None, VD=1.8, VB=0.0, T=300.0)

# %%
data = read_iv('2602', 4, meas_mode='idvd')
ax = plt.gca()

for dut_info, df in data:
    print(dut_info)
    plot_idvd(df, ax)
# Out:
# DUTinfo(die=1, mod='2602', idx=4, flavor='nfet', W=4.2e-07, L=1.5000000000000002e-07, meas_mode='idvd', VG=0.3, VD=None, VB=0.0, T=300.0)
# DUTinfo(die=1, mod='2602', idx=4, flavor='nfet', W=4.2e-07, L=1.5000000000000002e-07, meas_mode='idvd', VG=0.6, VD=None, VB=0.0, T=300.0)
# DUTinfo(die=1, mod='2602', idx=4, flavor='nfet', W=4.2e-07, L=1.5000000000000002e-07, meas_mode='idvd', VG=1.2, VD=None, VB=0.0, T=300.0)
# DUTinfo(die=1, mod='2602', idx=4, flavor='nfet', W=4.2e-07, L=1.5000000000000002e-07, meas_mode='idvd', VG=1.8, VD=None, VB=0.0, T=300.0)
